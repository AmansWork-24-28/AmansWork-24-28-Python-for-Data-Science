# %% [markdown]
# ![Screenshot 2026-07-14 230906.png](attachment:e7d92212-5136-4e62-b36f-90adf362ad2c.png)
#
# # TYPE OF FILES
#
# There are 2 types of files:
# 1. Text files (.txt, .c, etc)
# 2. Binary files (.jpg, .dat, etc)

# %% [markdown]
# # Opening a File
#
# Python has an open() function for opening files. It takes 2 parameters: filename and
# mode.

# %%
# file = open("filename", mode)

# %% [markdown]
# # Read File
#
# Doesnt Creates a new file if not exist

# %% [markdown]
# # Using read() – Read Entire File
#
# file = open("example.txt", "r")
# content = file.read()
# print(content)
# file.close()
# print()
#
# # Using readline() – Read Line by Line
#
# file = open("example.txt", "r")
# line1 = file.readline() # Reads first line
# print(line1)
# file.close()
#
# # Using readlines() – Read All Lines as List
#
# file = open("example.txt", "r")
# lines = file.readlines() # Reads all lines into a list
# print(lines)
# file.close()

# %% [markdown]
# # Write File
#
# Creates a new file if not exist

# %%
# Using write() – Overwrites Existing Content

file = open("example.txt", "w") # Opens file in write mode
file.write("Hello, World!") # Writes content
file.close()

# Using writelines() – Write Multiple Lines

lines = ["Hello\n", "Welcome to Python\n", "File Handling\n"]
file = open("example.txt", "w")
file.writelines(lines) # Writes multiple lines
file.close()

# %% [markdown]
# # Appending to a File
#
# Creates a new file if not exist

# %%
file = open("example.txt", "a")
file.write("\nThis is an additional line.")
file.close()

# %% [markdown]
# # Using with Statement (Best Practice)
#
# Using with open() ensures the file is automatically closed after execution.

# %%
# readmode
with open("example.txt", "r") as file:
 content = file.read()
print(content) 

# writemode
with open("example.txt", "a") as file:
    file.write("\nThis is a new line.")
    file.write("\nPython is awesome.")

print("Data appended successfully.")

# appendmode
with open("example.txt", "a") as file:
    file.write("\nThis is a new line.")
    file.write("\nPython is awesome.")

print("Data appended successfully.")
# Out:
# Hello
# Welcome to Python
# File Handling
#
# This is an additional line.
# This is an additional line.
# This is a new line.
# Python is awesome.
# This is a new line.
# Python is awesome.
# Data appended successfully.
# Data appended successfully.

# %%
with open("example.txt", "r") as file:
    for line in file:
        print(line)
# Out:
# Hello
#
# Welcome to Python
#
# File Handling
#
#
#
# This is an additional line.
#
# This is an additional line.
#
# This is a new line.
#
# Python is awesome.
#
# This is a new line.
#
# Python is awesome.
#
# This is a new line.
#
# Python is awesome.
#
# This is a new line.
#
# Python is awesome.
