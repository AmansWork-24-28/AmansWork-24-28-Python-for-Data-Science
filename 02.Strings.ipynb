# %%
str = "DataScience"
print(str)
type(str)
# Out:
# DataScience
# str

# %% [markdown]
# --> SLICING OF STRING
#
# string index starts from 0
# str[istart:iend]
# istart - included and iend - excluded

# %%
c = str[0:5]
c
# Out:
# 'DataS'

# %%
# Skipping value ->
    
str[0:8:2]
# Out:
# 'DtSi'

# %%
# FUNCTIONS OF STRING 

#1.Length of string
len(str)

#2.Count String charcters
str.count(str)

#3.Endswith (boolean)
str.endswith("e") #True
str.endswith("f") #False

#4.Captilize
str.capitalize() #make first capital 

#5.Find substring 
str.find("rr") #False
str.find("Da") #True

#6.Replace
str.replace("Sci", "sci")
# Out:
# 'Datascience'

# %% [markdown]
# ![image.png](attachment:477fa10d-e96c-41af-b37f-b159c3eb88e4.png)
